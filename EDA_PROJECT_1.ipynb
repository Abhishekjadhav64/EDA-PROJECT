# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekjadhav64/EDA-PROJECT/blob/main/EDA_PROJECT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the DataSet

# %%
df=pd.read_csv('/content/sample_data/data.csv',encoding = 'ISO-8859-1')

# %% [markdown]
# ## Number of Rows and Columns

# %%
df.shape
# Out:
# (25015, 8)

# %% [markdown]
# # Accessing First Five Rows

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # Accesing Last Five Rows

# %%
df.tail()
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 25010    538351     22149           FELTCRAFT 6 FLOWER FRIENDS        23
# 25011    538351     22150             3 STRIPEY MICE FELTCRAFT         1
# 25012    538351     22174                           PHOTO CUBE         4
# 25013    538351     22326  ROUND SNACK BOXES SET OF4 WOODLAND          1
# 25014    538351     22327    ROUND SNACK BOXES SET OF 4 SKULLS         2
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 25010  12/10/2010 15:17       5.06         NaN  United Kingdom
# 25011  12/10/2010 15:17       5.06         NaN  United Kingdom
# 25012  12/10/2010 15:17       4.21         NaN  United Kingdom
# 25013  12/10/2010 15:17       6.77         NaN  United Kingdom
# 25014  12/10/2010 15:17       6.77         NaN         United

# %% [markdown]
# # Displaying Total columns of DataSet

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# # Getting all columns one by one

# %%
for column in df.columns:
    print(column)
# Out:
# InvoiceNo
# StockCode
# Description
# Quantity
# InvoiceDate
# UnitPrice
# CustomerID
# Country

# %% [markdown]
# # Renaming column names

# %%
d={
    'InvoiceNo':'invoice_no',
    'StockCode':'stock_code',
    'Description':'description',
    'Quantity':'quantity',
    'InvoiceDate':'invoice_date',
    'UnitPrice':'unit_price',
    'CustomerID':'cust_id',
    'Country':'country'
}

# %%
d
# Out:
# {'InvoiceNo': 'invoice_no',
#  'StockCode': 'stock_code',
#  'Description': 'description',
#  'Quantity': 'quantity',
#  'InvoiceDate': 'invoice_date',
#  'UnitPrice': 'unit_price',
#  'CustomerID': 'cust_id',
#  'Country': 'country'}

# %%
df.rename(columns=d,inplace=True)

# %%
df
# Out:
#       invoice_no stock_code                          description  quantity  \
# 0         536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365      71053                  WHITE METAL LANTERN         6
# 2         536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...        ...                                  ...       ...
# 25010     538351      22149           FELTCRAFT 6 FLOWER FRIENDS        23
# 25011     538351      22150             3 STRIPEY MICE FELTCRAFT         1
# 25012     538351      22174                           PHOTO CUBE         4
# 25013     538351      22326  ROUND SNACK BOXES SET OF4 WOODLAND          1
# 25014     538351      22327    ROUND SNACK BOXES SET OF 4 SKULLS         2
#
#            invoice_date  unit_price  cust_id         country
# ...

# %%
df.columns
# Out:
# Index(['invoice_no', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'cust_id', 'country'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# invoice_no
# stock_code
# description
# quantity
# invoice_date
# unit_price
# cust_id
# country

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      invoice_date  unit_price  cust_id         country
# 0  12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 2  12/1/2010 8:26        2.75  17850.0  United Kingdom
# 3  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 4  12/1/2010 8:26        3.39  17850.0  United Kingdom

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Checking column types

# %%
df.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# cust_id         float64
# country          object
# dtype: object

# %% [markdown]
# # DataFrame Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25015 entries, 0 to 25014
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   invoice_no    25015 non-null  object
#  1   stock_code    25015 non-null  object
#  2   description   24904 non-null  object
#  3   quantity      25015 non-null  int64
#  4   invoice_date  25015 non-null  object
#  5   unit_price    25015 non-null  float64
#  6   cust_id       16056 non-null  float64
#  7   country       25015 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# # Checking missing values from each columns

# %%
df.isnull()
# Out:
#        invoice_no  stock_code  description  quantity  invoice_date  \
# 0           False       False        False     False         False
# 1           False       False        False     False         False
# 2           False       False        False     False         False
# 3           False       False        False     False         False
# 4           False       False        False     False         False
# ...           ...         ...          ...       ...           ...
# 25010       False       False        False     False         False
# 25011       False       False        False     False         False
# 25012       False       False        False     False         False
# 25013       False       False        False     False         False
# 25014       False       False        False     False         False
#
#        unit_price  cust_id  country
# 0           False    False    False
# 1           False    False    False
# 2           False    False    False
# ...

# %% [markdown]
# # Checking Number of Columns

# %%
len(df.columns)
# Out:
# 8

# %%
df.shape
# Out:
# (25015, 8)

# %% [markdown]
# # Checking missing values count of each column

# %%
df.isnull().sum()
# Out:
# invoice_no         0
# stock_code         0
# description      111
# quantity           0
# invoice_date       0
# unit_price         0
# cust_id         8959
# country            0
# dtype: int64

# %% [markdown]
# # Checking missing values count of each column ,applying sorting

# %%
df.isnull().sum().sort_values()
# Out:
# invoice_no         0
# stock_code         0
# quantity           0
# invoice_date       0
# unit_price         0
# country            0
# description      111
# cust_id         8959
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# cust_id         8959
# description      111
# invoice_no         0
# stock_code         0
# quantity           0
# invoice_date       0
# unit_price         0
# country            0
# dtype: int64

# %% [markdown]
# # checking type of invoice_date column

# %%
df.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# cust_id         float64
# country          object
# dtype: object

# %% [markdown]
# # Access inital date

# %%
df.head(2)
# Out:
#   invoice_no stock_code                         description  quantity  \
# 0     536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                 WHITE METAL LANTERN         6
#
#      invoice_date  unit_price  cust_id         country
# 0  12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39  17850.0  United Kingdom

# %% [markdown]
# # Converting invoice_date data type into datatime data type

# %%
df['invoice_date'] = pd.to_datetime(df.invoice_date, format='%m/%d/%Y %H:%M')

# %% [markdown]
# # Checking type of invoice_date

# %%
df.dtypes
# Out:
# invoice_no              object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# cust_id                float64
# country                 object
# dtype: object

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# # Let us check description column

# %%
df.description
# Out:
# 0         WHITE HANGING HEART T-LIGHT HOLDER
# 1                        WHITE METAL LANTERN
# 2             CREAM CUPID HEARTS COAT HANGER
# 3        KNITTED UNION FLAG HOT WATER BOTTLE
# 4             RED WOOLLY HOTTIE WHITE HEART.
#                         ...
# 25010             FELTCRAFT 6 FLOWER FRIENDS
# 25011               3 STRIPEY MICE FELTCRAFT
# 25012                             PHOTO CUBE
# 25013    ROUND SNACK BOXES SET OF4 WOODLAND
# 25014      ROUND SNACK BOXES SET OF 4 SKULLS
# Name: description, Length: 25015, dtype: object

# %% [markdown]
# # We need to call lower() method

# %%
df.description.str.lower()
# Out:
# 0         white hanging heart t-light holder
# 1                        white metal lantern
# 2             cream cupid hearts coat hanger
# 3        knitted union flag hot water bottle
# 4             red woolly hottie white heart.
#                         ...
# 25010             feltcraft 6 flower friends
# 25011               3 stripey mice feltcraft
# 25012                             photo cube
# 25013    round snack boxes set of4 woodland
# 25014      round snack boxes set of 4 skulls
# Name: description, Length: 25015, dtype: object

# %%
df.head(3)
# Out:
#   invoice_no stock_code                         description  quantity  \
# 0     536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                 WHITE METAL LANTERN         6
# 2     536365     84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom

# %%
df['description'] = df.description.str.lower()

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# # Missing values

# %% [markdown]
# # Based on team meeting/client discussion we will need to perform accordingly

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# cust_id         8959
# description      111
# invoice_no         0
# stock_code         0
# quantity           0
# invoice_date       0
# unit_price         0
# country            0
# dtype: int64

# %% [markdown]
# # Dropping missing values

# %%
df_new = df.dropna()

# %% [markdown]
# # After dropping missing values then again Checking missing values for each columns

# %%
df_new.isnull().sum()
# Out:
# invoice_no      0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# cust_id         0
# country         0
# dtype: int64

# %% [markdown]
# # DataFrame information

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16056 entries, 0 to 24936
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   invoice_no    16056 non-null  object
#  1   stock_code    16056 non-null  object
#  2   description   16056 non-null  object
#  3   quantity      16056 non-null  int64
#  4   invoice_date  16056 non-null  datetime64[ns]
#  5   unit_price    16056 non-null  float64
#  6   cust_id       16056 non-null  float64
#  7   country       16056 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# # Check type of cust_id data type

# %%
df_new.dtypes
# Out:
# invoice_no              object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# cust_id                float64
# country                 object
# dtype: object

# %% [markdown]
# # Converting cust_id float type into integer type

# %%
df_new['cust_id']
# Out:
# 0        17850.0
# 1        17850.0
# 2        17850.0
# 3        17850.0
# 4        17850.0
#           ...
# 24932    13798.0
# 24933    13798.0
# 24934    13798.0
# 24935    13798.0
# 24936    13798.0
# Name: cust_id, Length: 16056, dtype: float64

# %% [markdown]
# # Ignoring warnings in google Collab

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_new['cust_id'] = df_new['cust_id'].astype('int64')

# %% [markdown]
# #Accessing first five rows

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %% [markdown]
# # New DataFrame information

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16056 entries, 0 to 24936
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   invoice_no    16056 non-null  object
#  1   stock_code    16056 non-null  object
#  2   description   16056 non-null  object
#  3   quantity      16056 non-null  int64
#  4   invoice_date  16056 non-null  datetime64[ns]
#  5   unit_price    16056 non-null  float64
#  6   cust_id       16056 non-null  int64
#  7   country       16056 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# # DataFrame description

# %%
df_new.describe()
# Out:
#            quantity                   invoice_date    unit_price       cust_id
# count  16056.000000                          16056  16056.000000  16056.000000
# mean       9.817389  2010-12-06 00:43:20.676382464      3.162644  15572.953288
# min    -9360.000000            2010-12-01 08:26:00      0.000000  12347.000000
# 25%        1.000000            2010-12-03 09:31:00      1.250000  14135.000000
# 50%        4.000000            2010-12-06 10:36:00      2.100000  15647.500000
# 75%       12.000000            2010-12-08 13:01:00      3.750000  17223.000000
# max     2880.000000            2010-12-10 15:01:00    295.000000  18269.000000
# std       87.243061                            NaN      5.455808   1782.224395

# %% [markdown]
# #Rounding the values in DataFrame

# %%
df_new.describe().round(2)
# Out:
#        quantity                   invoice_date  unit_price   cust_id
# count  16056.00                          16056    16056.00  16056.00
# mean       9.82  2010-12-06 00:43:20.676382464        3.16  15572.95
# min    -9360.00            2010-12-01 08:26:00        0.00  12347.00
# 25%        1.00            2010-12-03 09:31:00        1.25  14135.00
# 50%        4.00            2010-12-06 10:36:00        2.10  15647.50
# 75%       12.00            2010-12-08 13:01:00        3.75  17223.00
# max     2880.00            2010-12-10 15:01:00      295.00  18269.00
# std       87.24                            NaN        5.46   1782.22

# %% [markdown]
# #Let us do some analysis
# #Conclusion is: quantity column having negative values So, we need to remove/delete negative values

# %%
df_new.quantity > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 24932    False
# 24933    False
# 24934    False
# 24935    False
# 24936    False
# Name: quantity, Length: 16056, dtype: bool

# %%
con = df_new.quantity > 0

# %%
df_new = df_new[con]

# %%
df_new.describe().round(2)
# Out:
#        quantity                   invoice_date  unit_price   cust_id
# count  15691.00                          15691    15691.00  15691.00
# mean      10.84  2010-12-05 23:57:48.666114560        3.10  15580.78
# min        1.00            2010-12-01 08:26:00        0.00  12347.00
# 25%        1.00            2010-12-02 19:59:00        1.25  14135.00
# 50%        4.00            2010-12-06 10:05:00        2.10  15694.00
# 75%       12.00            2010-12-08 12:46:00        3.75  17228.00
# max     2880.00            2010-12-10 14:54:00      295.00  18269.00
# std       46.61                            NaN        4.55   1787.00

# %% [markdown]
# #Access initial Data

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %% [markdown]
# #Checking total number of rows and columns

# %%
df_new.shape
# Out:
# (15691, 8)

# %% [markdown]
# #Adding the column - amount_spent

# %%
df_new['amount_spent'] = df_new['quantity'] * df_new['unit_price']

# %%
df_new.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   white hanging heart t-light holder         6
# 1     536365      71053                  white metal lantern         6
# 2     536365     84406B       cream cupid hearts coat hanger         8
# 3     536365     84029G  knitted union flag hot water bottle         6
# 4     536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34

# %% [markdown]
# #Lets read the column names from DataFrame

# %%
for col in df_new.columns:
    print(col)
# Out:
# invoice_no
# stock_code
# description
# quantity
# invoice_date
# unit_price
# cust_id
# country
# amount_spent

# %% [markdown]
# #Rearranging columns for more readability

# %%
col_order = ['invoice_no','invoice_date','stock_code','description','quantity','unit_price','amount_spent','cust_id','country']

# %%
df_new = df_new[col_order]

# %% [markdown]
# #Access initial data

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date stock_code  \
# 0     536365 2010-12-01 08:26:00     85123A
# 1     536365 2010-12-01 08:26:00      71053
# 2     536365 2010-12-01 08:26:00     84406B
# 3     536365 2010-12-01 08:26:00     84029G
# 4     536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %% [markdown]
# #Number of rows and columns

# %%
df_new.shape
# Out:
# (15691, 9)

# %% [markdown]
# #Let us do analysis on invoice_date column number of columns in the dataset

# %%
len(df_new.columns)
# Out:
# 9

# %% [markdown]
# #Accessing invoice_date column

# %%
df_new['invoice_date']
# Out:
# 0       2010-12-01 08:26:00
# 1       2010-12-01 08:26:00
# 2       2010-12-01 08:26:00
# 3       2010-12-01 08:26:00
# 4       2010-12-01 08:26:00
#                 ...
# 24285   2010-12-10 14:54:00
# 24286   2010-12-10 14:54:00
# 24287   2010-12-10 14:54:00
# 24288   2010-12-10 14:54:00
# 24289   2010-12-10 14:54:00
# Name: invoice_date, Length: 15691, dtype: datetime64[ns]

# %% [markdown]
# #Accessing year value from invoice_date

# %%
df_new['invoice_date'].dt.year
# Out:
# 0        2010
# 1        2010
# 2        2010
# 3        2010
# 4        2010
#          ...
# 24285    2010
# 24286    2010
# 24287    2010
# 24288    2010
# 24289    2010
# Name: invoice_date, Length: 15691, dtype: int32

# %% [markdown]
# #Accessing month value from invoice_date

# %%
df_new['invoice_date'].dt.month
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 24285    12
# 24286    12
# 24287    12
# 24288    12
# 24289    12
# Name: invoice_date, Length: 15691, dtype: int32

# %% [markdown]
# #Access initial Data

# %%
df_new.head(2)
# Out:
#   invoice_no        invoice_date stock_code  \
# 0     536365 2010-12-01 08:26:00     85123A
# 1     536365 2010-12-01 08:26:00      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom

# %% [markdown]
# #Lets insert year_month colum in 2nd position

# %% [markdown]
# #small calculation

# %%
y = 2010
m = 12

# %%
y_m = 100*2010 + 12

# %%
y_m
# Out:
# 201012

# %%
c1 = 'year_month'

# %%
v1 = df_new['invoice_date'].map(lambda col: 100*(col.year) + col.month)

# %%
df_new.insert(loc = 2, column = c1, value = v1)

# %%
df_new
# Out:
#       invoice_no        invoice_date  year_month stock_code  \
# 0         536365 2010-12-01 08:26:00      201012     85123A
# 1         536365 2010-12-01 08:26:00      201012      71053
# 2         536365 2010-12-01 08:26:00      201012     84406B
# 3         536365 2010-12-01 08:26:00      201012     84029G
# 4         536365 2010-12-01 08:26:00      201012     84029E
# ...          ...                 ...         ...        ...
# 24285     538347 2010-12-10 14:54:00      201012      22415
# 24286     538347 2010-12-10 14:54:00      201012      21098
# 24287     538347 2010-12-10 14:54:00      201012      22960
# 24288     538347 2010-12-10 14:54:00      201012      22961
# 24289     538347 2010-12-10 14:54:00      201012      21813
#
#                                description  quantity  unit_price  \
# 0       white hanging heart t-light holder         6        2.55
# 1                      white metal lantern         6        3.39
# ...

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year_month stock_code  \
# 0     536365 2010-12-01 08:26:00      201012     85123A
# 1     536365 2010-12-01 08:26:00      201012      71053
# 2     536365 2010-12-01 08:26:00      201012     84406B
# 3     536365 2010-12-01 08:26:00      201012     84029G
# 4     536365 2010-12-01 08:26:00      201012     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %% [markdown]
# #Adding month column to the exisint DataFrame

# %%
c2 = 'month'
v2 = df_new.invoice_date.dt.month
df_new.insert(loc = 3, column = c2, value = v2)
df_new.head()
# Out:
#   invoice_no        invoice_date  year_month  month stock_code  \
# 0     536365 2010-12-01 08:26:00      201012     12     85123A
# 1     536365 2010-12-01 08:26:00      201012     12      71053
# 2     536365 2010-12-01 08:26:00      201012     12     84406B
# 3     536365 2010-12-01 08:26:00      201012     12     84029G
# 4     536365 2010-12-01 08:26:00      201012     12     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# ...

# %% [markdown]
# #Lets access invoice_date column

# %%
df_new.invoice_date
# Out:
# 0       2010-12-01 08:26:00
# 1       2010-12-01 08:26:00
# 2       2010-12-01 08:26:00
# 3       2010-12-01 08:26:00
# 4       2010-12-01 08:26:00
#                 ...
# 24285   2010-12-10 14:54:00
# 24286   2010-12-10 14:54:00
# 24287   2010-12-10 14:54:00
# 24288   2010-12-10 14:54:00
# 24289   2010-12-10 14:54:00
# Name: invoice_date, Length: 15691, dtype: datetime64[ns]

# %% [markdown]
# #We can get day of the week

# %%
df_new.invoice_date.dt.dayofweek
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 24285    4
# 24286    4
# 24287    4
# 24288    4
# 24289    4
# Name: invoice_date, Length: 15691, dtype: int32

# %% [markdown]
# #In pandas, the day formate starts from 0 to 6.Apply +1 to make Monday = 1.....until Sunday = 7

# %%
c3 = 'day'
v3 = (df_new.invoice_date.dt.dayofweek)+1
df_new.insert(loc = 4, column = c3, value = v3)
df_new.head()
# Out:
#   invoice_no        invoice_date  year_month  month  day stock_code  \
# 0     536365 2010-12-01 08:26:00      201012     12    3     85123A
# 1     536365 2010-12-01 08:26:00      201012     12    3      71053
# 2     536365 2010-12-01 08:26:00      201012     12    3     84406B
# 3     536365 2010-12-01 08:26:00      201012     12    3     84029G
# 4     536365 2010-12-01 08:26:00      201012     12    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# ...

# %% [markdown]
# #Adding hour column to existing DataFrame

# %%
df_new.invoice_date
# Out:
# 0       2010-12-01 08:26:00
# 1       2010-12-01 08:26:00
# 2       2010-12-01 08:26:00
# 3       2010-12-01 08:26:00
# 4       2010-12-01 08:26:00
#                 ...
# 24285   2010-12-10 14:54:00
# 24286   2010-12-10 14:54:00
# 24287   2010-12-10 14:54:00
# 24288   2010-12-10 14:54:00
# 24289   2010-12-10 14:54:00
# Name: invoice_date, Length: 15691, dtype: datetime64[ns]

# %%
# dir(df_new.invoice_date)
# dir(df_new.invoice_date.dt)
# df_new.invoice_date.dt.hour
c4 = "hour"
v4 = df_new.invoice_date.dt.hour
df_new.insert(loc = 5, column = c4, value = v4)
df_new.head()
# Out:
#   invoice_no        invoice_date  year_month  month  day  hour stock_code  \
# 0     536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1     536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2     536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3     536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4     536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %% [markdown]
# #Lets display all columns once

# %%
df_new.columns
# Out:
# Index(['invoice_no', 'invoice_date', 'year_month', 'month', 'day', 'hour',
#        'stock_code', 'description', 'quantity', 'unit_price', 'amount_spent',
#        'cust_id', 'country'],
#       dtype='object')

# %%
for col in df_new.columns:
    print(col)
# Out:
# invoice_no
# invoice_date
# year_month
# month
# day
# hour
# stock_code
# description
# quantity
# unit_price
# amount_spent
# cust_id
# country

# %% [markdown]
# #Exploratory Data Analysis (EDA)

# %%
df_new.groupby(by = ['cust_id']).count()
# Out:
#          invoice_no  invoice_date  year_month  month  day  hour  stock_code  \
# cust_id
# 12347            31            31          31     31   31    31          31
# 12386             8             8           8      8    8     8           8
# 12395            12            12          12     12   12    12          12
# 12427            10            10          10     10   10    10          10
# 12429            20            20          20     20   20    20          20
# ...             ...           ...         ...    ...  ...   ...         ...
# 18225             2             2           2      2    2     2           2
# 18229            10            10          10     10   10    10          10
# 18239            29            29          29     29   29    29          29
# 18259             7             7           7      7    7     7           7
# 18269             7             7           7      7    7     7           7
#
# ...

# %%
df_new.groupby(by = ['cust_id','country']).count()
# Out:
#                         invoice_no  invoice_date  year_month  month  day  \
# cust_id country
# 12347   Iceland                 31            31          31     31   31
# 12386   Australia                8             8           8      8    8
# 12395   Belgium                 12            12          12     12   12
# 12427   Germany                 10            10          10     10   10
# 12429   Denmark                 20            20          20     20   20
# ...                            ...           ...         ...    ...  ...
# 18225   United Kingdom           2             2           2      2    2
# 18229   United Kingdom          10            10          10     10   10
# 18239   United Kingdom          29            29          29     29   29
# 18259   United Kingdom           7             7           7      7    7
# 18269   United Kingdom           7             7           7      7    7
#
# ...

# %%
df_new.groupby(by = ['cust_id','country'])['invoice_no'].count()
# Out:
# cust_id  country
# 12347    Iceland           31
# 12386    Australia          8
# 12395    Belgium           12
# 12427    Germany           10
# 12429    Denmark           20
#                            ..
# 18225    United Kingdom     2
# 18229    United Kingdom    10
# 18239    United Kingdom    29
# 18259    United Kingdom     7
# 18269    United Kingdom     7
# Name: invoice_no, Length: 608, dtype: int64

# %%
df_new.groupby(by = ['cust_id','country'], as_index = False)['invoice_no'].count()
# Out:
#      cust_id         country  invoice_no
# 0      12347         Iceland          31
# 1      12386       Australia           8
# 2      12395         Belgium          12
# 3      12427         Germany          10
# 4      12429         Denmark          20
# ..       ...             ...         ...
# 603    18225  United Kingdom           2
# 604    18229  United Kingdom          10
# 605    18239  United Kingdom          29
# 606    18259  United Kingdom           7
# 607    18269  United Kingdom           7
#
# [608 rows x 3 columns]

# %%
df_new.groupby(by=['cust_id','country'], as_index=False)['invoice_no'].count().head()
# Out:
#    cust_id    country  invoice_no
# 0    12347    Iceland          31
# 1    12386  Australia           8
# 2    12395    Belgium          12
# 3    12427    Germany          10
# 4    12429    Denmark          20

# %% [markdown]
# #Data Visaulization libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_new.groupby(by=['cust_id','country'], as_index=False)['invoice_no'].count()
# Out:
#      cust_id         country  invoice_no
# 0      12347         Iceland          31
# 1      12386       Australia           8
# 2      12395         Belgium          12
# 3      12427         Germany          10
# 4      12429         Denmark          20
# ..       ...             ...         ...
# 603    18225  United Kingdom           2
# 604    18229  United Kingdom          10
# 605    18239  United Kingdom          29
# 606    18259  United Kingdom           7
# 607    18269  United Kingdom           7
#
# [608 rows x 3 columns]

# %%
orders = df_new.groupby(by=['cust_id','country'], as_index=False)['invoice_no'].count()

# %%
 orders
# Out:
#      cust_id         country  invoice_no
# 0      12347         Iceland          31
# 1      12386       Australia           8
# 2      12395         Belgium          12
# 3      12427         Germany          10
# 4      12429         Denmark          20
# ..       ...             ...         ...
# 603    18225  United Kingdom           2
# 604    18229  United Kingdom          10
# 605    18239  United Kingdom          29
# 606    18259  United Kingdom           7
# 607    18269  United Kingdom           7
#
# [608 rows x 3 columns]

# %% [markdown]
# #Check TOP 5 most number of orders

# %%
orders.sort_values(by = 'invoice_no', ascending = False).head()
# Out:
#      cust_id         country  invoice_no
# 31     12748  United Kingdom         544
# 548    17850  United Kingdom         297
# 235    14911            EIRE         212
# 547    17841  United Kingdom         186
# 84     13174  United Kingdom         169

# %% [markdown]
# #Visualizing - Number of Orders for different Customers

# %%
orders = df_new.groupby(by=['cust_id','country'], as_index=False)['invoice_no'].count()

plt.subplots(figsize=(15,6))

plt.plot(orders.cust_id, orders.invoice_no)

plt.xlabel('Customers ID')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different Customers')

plt.show()

# %% [markdown]
# #How much money spent by each customers?

# %%
df_new.groupby(by = ['cust_id', 'country'])['invoice_no'].sum()
# Select the numeric column 'invoice_no' explicitly for summation after grouping.
# This assumes 'invoice_no' contains numeric values you want to sum.
# If you intend to sum a different numeric column, replace 'invoice_no' accordingly.
# Out:
# cust_id  country
# 12347    Iceland           5376265376265376265376265376265376265376265376...
# 12386    Australia          537676537676537676537676537676537676537676537676
# 12395    Belgium           5370265370265370265370265370265370265370265370...
# 12427    Germany           5368615368615368615368615368615368615368615368...
# 12429    Denmark           5380035380035380035380035380035380035380035380...
#                                                  ...
# 18225    United Kingdom                                         538125538125
# 18229    United Kingdom    5365865365865365865365865365865365865365865377...
# 18239    United Kingdom    5368335368335368335368335368335368335368335368...
# 18259    United Kingdom           537813537813537813537813537813537813537813
# 18269    United Kingdom           537817537817537817537817537817537817537817
# Name: invoice_no, Length: 608, dtype: object

# %%
df_new.groupby(by = ['cust_id', 'country'])['amount_spent'].sum()
# Out:
# cust_id  country
# 12347    Iceland            711.79
# 12386    Australia          258.90
# 12395    Belgium            346.10
# 12427    Germany            303.50
# 12429    Denmark           1281.50
#                             ...
# 18225    United Kingdom      30.00
# 18229    United Kingdom     653.20
# 18239    United Kingdom     438.10
# 18259    United Kingdom     376.30
# 18269    United Kingdom     168.60
# Name: amount_spent, Length: 608, dtype: float64

# %%
df_new.groupby(by = ['cust_id', 'country'], as_index = False)['amount_spent'].sum()
# Out:
#      cust_id         country  amount_spent
# 0      12347         Iceland        711.79
# 1      12386       Australia        258.90
# 2      12395         Belgium        346.10
# 3      12427         Germany        303.50
# 4      12429         Denmark       1281.50
# ..       ...             ...           ...
# 603    18225  United Kingdom         30.00
# 604    18229  United Kingdom        653.20
# 605    18239  United Kingdom        438.10
# 606    18259  United Kingdom        376.30
# 607    18269  United Kingdom        168.60
#
# [608 rows x 3 columns]

# %%
money_spent = df_new.groupby(by = ['cust_id', 'country'], as_index = False)['amount_spent'].sum()

# %%
money_spent
# Out:
#      cust_id         country  amount_spent
# 0      12347         Iceland        711.79
# 1      12386       Australia        258.90
# 2      12395         Belgium        346.10
# 3      12427         Germany        303.50
# 4      12429         Denmark       1281.50
# ..       ...             ...           ...
# 603    18225  United Kingdom         30.00
# 604    18229  United Kingdom        653.20
# 605    18239  United Kingdom        438.10
# 606    18259  United Kingdom        376.30
# 607    18269  United Kingdom        168.60
#
# [608 rows x 3 columns]

# %% [markdown]
# #Top FIVE customers who spend highest money

# %%
money_spent.sort_values(by='amount_spent', ascending = False).head()
# Out:
#      cust_id         country  amount_spent
# 592    18102  United Kingdom      27834.61
# 251    15061  United Kingdom      17344.78
# 128    13777  United Kingdom       6840.16
# 235    14911            EIRE       5567.63
# 548    17850  United Kingdom       5391.21

# %% [markdown]
# #Top TEN customers who spend highest money

# %%
money_spent.sort_values(by='amount_spent', ascending = False).head(10)
# Out:
#      cust_id         country  amount_spent
# 592    18102  United Kingdom      27834.61
# 251    15061  United Kingdom      17344.78
# 128    13777  United Kingdom       6840.16
# 235    14911            EIRE       5567.63
# 548    17850  United Kingdom       5391.21
# 376    16210  United Kingdom       4738.54
# 357    16029  United Kingdom       4271.52
# 32     12755           Japan       3794.40
# 6      12433          Norway       3787.12
# 490    17381  United Kingdom       3603.72

# %% [markdown]
# #Visualizing - Money spent for different customers

# %%
money_spent = df_new.groupby(by=['cust_id','country'], as_index=False)['amount_spent'].sum()

plt.subplots(figsize=(15,6))

plt.plot(money_spent.cust_id, money_spent.amount_spent)

plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')

plt.show()

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year_month  month  day  hour stock_code  \
# 0     536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1     536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2     536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3     536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4     536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %% [markdown]
# #Number of order for different months

# %%
color = sns.color_palette()

# %% [markdown]
# #Initial Data

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year_month  month  day  hour stock_code  \
# 0     536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1     536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2     536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3     536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4     536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %%
df_new.groupby('invoice_no')

# %%
 df_new.groupby('invoice_no')['year_month']

# %%
df_new.groupby('invoice_no')['year_month'].unique()
# Out:
# invoice_no
# 536365    [201012]
# 536366    [201012]
# 536367    [201012]
# 536368    [201012]
# 536369    [201012]
#             ...
# 538342    [201012]
# 538343    [201012]
# 538345    [201012]
# 538346    [201012]
# 538347    [201012]
# Name: year_month, Length: 840, dtype: object

# %%
df_new.groupby('invoice_no')['year_month'].unique().value_counts()
# Out:
# year_month
# [201012]    840
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_no')['year_month'].unique().value_counts().sort_index()
# Out:
# year_month
# [201012]    840
# Name: count, dtype: int64

# %%
# Assuming df_new is your DataFrame and color is defined
ax = df_new.groupby('invoice_no')['year_month'].unique().value_counts().sort_index().plot(kind='bar', color=color[0], figsize=(15, 6))

ax.set_xlabel('Month and Year', fontsize=15)
ax.set_ylabel('Number of Orders', fontsize=15)
ax.set_title('Number of orders for different Months (1st Dec 2010 - 9th Dec 2011)', fontsize=15)

# Your labels
t = ('Dec_10', 'Jan_11', 'Feb_11', 'Mar_11', 'Apr_11', 'May_11', 'Jun_11', 'Jul_11', 'Aug_11', 'Sep_11', 'Oct_11', 'Nov_11', 'Dec_11')

# Set the x-ticks to match the number of bars
ax.set_xticks(range(len(t)))

# Now set the x-tick labels
ax.set_xticklabels(t, rotation='horizontal', fontsize=13)

plt.show()

# %% [markdown]
# #How many orders (per day)?

# %%
df_new.groupby('invoice_no')

# %%
df_new.groupby('invoice_no')['day']

# %%
df_new.groupby('invoice_no')['day'].unique()
# Out:
# invoice_no
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 538342    [5]
# 538343    [5]
# 538345    [5]
# 538346    [5]
# 538347    [5]
# Name: day, Length: 840, dtype: object

# %%
df_new.groupby('invoice_no')['day'].unique().value_counts()
# Out:
# day
# [4]    235
# [3]    232
# [5]    121
# [1]     94
# [7]     87
# [2]     71
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_no')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]     94
# [2]     71
# [3]    232
# [4]    235
# [5]    121
# [7]     87
# Name: count, dtype: int64

# %% [markdown]
# #Day wise sales count/business

# %%
df_new.head()
# Out:
#   invoice_no        invoice_date  year_month  month  day  hour stock_code  \
# 0     536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1     536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2     536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3     536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4     536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# ...

# %%
df_new.groupby('invoice_no')

# %%
df_new.groupby('invoice_no')['day']

# %%
df_new.groupby('invoice_no')['day'].unique()
# Out:
# invoice_no
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 538342    [5]
# 538343    [5]
# 538345    [5]
# 538346    [5]
# 538347    [5]
# Name: day, Length: 840, dtype: object

# %%
df_new.groupby('invoice_no')['day'].unique().value_counts()
# Out:
# day
# [4]    235
# [3]    232
# [5]    121
# [1]     94
# [7]     87
# [2]     71
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_no')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]     94
# [2]     71
# [3]    232
# [4]    235
# [5]    121
# [7]     87
# Name: count, dtype: int64

# %% [markdown]
# #Lets visualize Day wise sales count/business

# %%
ax = df_new.groupby('invoice_no')['day'].unique().value_counts().sort_index().plot(kind = 'bar',color=color[0],figsize=(15,6))

ax.set_xlabel('Day',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Days',fontsize=15)
d = ('Mon','Tue','Wed','Thur','Fri','Sun')
ax.set_xticklabels(d, rotation='horizontal', fontsize=15)
plt.show()

# %% [markdown]
# #Discover patterns for Unit Price

# %%
df_new.unit_price.describe()
# Out:
# count    15691.000000
# mean         3.102092
# std          4.546635
# min          0.000000
# 25%          1.250000
# 50%          2.100000
# 75%          3.750000
# max        295.000000
# Name: unit_price, dtype: float64

# %% [markdown]
# #Min value for product is zero, so there are some free products

# %%
# check the distribution of unit price
plt.subplots(figsize = (12,6))

sns.boxplot(df_new.unit_price)
plt.show()

# %% [markdown]
# #Filter only free products(cost = 0)

# %%
df_free = df_new[df_new.unit_price == 0]
len(df_free)
# Out:
# 1

# %%
df_free.year_month
# Out:
# 9302    201012
# Name: year_month, dtype: int64

# %%
df_free.year_month.value_counts()
# Out:
# year_month
# 201012    1
# Name: count, dtype: int64

# %%
df_free.year_month.value_counts().sort_index()
# Out:
# year_month
# 201012    1
# Name: count, dtype: int64

# %%
df_new
# Out:
#       invoice_no        invoice_date  year_month  month  day  hour stock_code  \
# 0         536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1         536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2         536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3         536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4         536365 2010-12-01 08:26:00      201012     12    3     8     84029E
# ...          ...                 ...         ...    ...  ...   ...        ...
# 24285     538347 2010-12-10 14:54:00      201012     12    5    14      22415
# 24286     538347 2010-12-10 14:54:00      201012     12    5    14      21098
# 24287     538347 2010-12-10 14:54:00      201012     12    5    14      22960
# 24288     538347 2010-12-10 14:54:00      201012     12    5    14      22961
# 24289     538347 2010-12-10 14:54:00      201012     12    5    14      21813
#
# ...

# %% [markdown]
# #How many orders for each country?

# %%
group_country_orders = df_new.groupby('country')['invoice_no'].count().sort_values()
# del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
group_country_orders = df_new.groupby('country')['invoice_no'].count().sort_values()
del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %% [markdown]
# #How much money spent by each country?

# %%
df_new
# Out:
#       invoice_no        invoice_date  year_month  month  day  hour stock_code  \
# 0         536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1         536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2         536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3         536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4         536365 2010-12-01 08:26:00      201012     12    3     8     84029E
# ...          ...                 ...         ...    ...  ...   ...        ...
# 24285     538347 2010-12-10 14:54:00      201012     12    5    14      22415
# 24286     538347 2010-12-10 14:54:00      201012     12    5    14      21098
# 24287     538347 2010-12-10 14:54:00      201012     12    5    14      22960
# 24288     538347 2010-12-10 14:54:00      201012     12    5    14      22961
# 24289     538347 2010-12-10 14:54:00      201012     12    5    14      21813
#
# ...

# %%
df_new.groupby('country')

# %%
df_new.groupby('country')['amount_spent']

# %%
df_new.groupby('country')['amount_spent'].sum()
# Out:
# country
# Australia             617.15
# Belgium               346.10
# Channel Islands       363.53
# Denmark              1281.50
# EIRE                 5889.83
# France               7362.32
# Germany              8044.49
# Iceland               711.79
# Italy                 427.80
# Japan                4114.48
# Lithuania            1661.06
# Netherlands           192.60
# Norway               3787.12
# Poland                248.16
# Portugal             1976.47
# Spain                 794.72
# Switzerland           303.40
# United Kingdom     299918.24
# Name: amount_spent, dtype: float64

# %%
df_new.groupby('country')['amount_spent'].sum().sort_values()
# Out:
# country
# Netherlands           192.60
# Poland                248.16
# Switzerland           303.40
# Belgium               346.10
# Channel Islands       363.53
# Italy                 427.80
# Australia             617.15
# Iceland               711.79
# Spain                 794.72
# Denmark              1281.50
# Lithuania            1661.06
# Portugal             1976.47
# Norway               3787.12
# Japan                4114.48
# EIRE                 5889.83
# France               7362.32
# Germany              8044.49
# United Kingdom     299918.24
# Name: amount_spent, dtype: float64

# %% [markdown]
# #How much money spent by each country?

# %%
group_country_amount_spent = df_new.groupby('country')['amount_spent'].sum().sort_values()
# del group_country_orders['United Kingdom']

# plot total money spent by each country (with UK)
plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %%
group_country_amount_spent = df_new.groupby('country')['amount_spent'].sum().sort_values()
del group_country_amount_spent['United Kingdom']

# plot total money spent by each country (without UK)
plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()
